# %% [markdown]
# # Day 11 Reading Journal
#
# Reading:
#  - _Ethics of Text Mining_. Please read the highlighted sections from the PDF posted on Canvas. The entire chapter is also [available online](https://www.sciencedirect.com/science/article/pii/B9781843347491000032) (without highlights)
#  - _Think Python_ [Chapter 14.1-14.4](http://www.greenteapress.com/thinkpython2/html/thinkpython2015.html)

# %% [markdown]
# ## If You Find Yourself in a Hole, Stop Digging: Legal and Ethical Issues of Text/Data Mining in Research
#
# We'll discuss this reading more in class next time. For now, we'd like you to consider the following questions as you read:
#
# Section 3.2.2 discusses the potential conflict between protecting personally identifiable information (PII) and the desire to analyze large data sets using "Big Data" techniques. The PII principles and conflicts are summarized in the table below.
#
# | Principle | PII protection rationale | Incompatibility with "Big Data" analysis |
# | --------- | ------------------------ | ---------------------------------------- |
# | Collection Limitation | There should be limits to the collection of PII, it should be obtained by lawfully and fairly and, ideally, with the knowledge/consent of the data subject | The larger the data collection, the better the potential for identifying interesting correlations |
# | Data Quality | PII should be relevant to the purposes for which it is to be used, and should be accurate, complete and up-to-date enough for those purposes | “Messy data” is fine, it’s not clear what is relevant until its analysed, and even inaccurate or incomplete data can be useful |
# | Purpose Specification | purposes for which PII are collected should be specified at the time of data collection. Subsequent use should be limited to those purposes or such others compatible with those purposes and specified on each change of purpose. | Data may have been collected for a particular purpose, but analysis may indicate further unrelated and previously unknown, but valuable, purposes. Data as collected may not be obviously PII, but analysis of it may identify individuals |
# | Use Limitation | PII should not be disclosed, made available or otherwise used for unspecified purposes except with data subject consent or by authority of law. | There may be value in sharing and aggregating data that may not be apparent at the time of collection |
# | Security Safeguards | PII should be protected by reasonable security safeguards against such risks as loss or unauthorised access, destruction, use, modification or disclosure of data. | It may be unclear what security issues, if any, arise from a particular collection of data or its analysis |
# | Openness | data subjects should be able to establish the existence and nature of PII, and the main purposes of its use, and the identity and location of the data controller. | Where data is collected and analysed, it may not be obvious that it is PII, and even in circumstances where it is, the researcher may have no way of informing the data subject of its use |
# | Individual Participation | An individual should be able to be informed by a data controller whether it holds PII relating to him or her; to have the PII communicated to him or her in meaningful form and reasonable time and at reasonable cost; to be informed if the PII will not be communicated and to be able to challenge that denial, where the PII is not lawfully held to have it erased, rectified, completed or amended. | Data that is anonymous may still be utilised in ways that can cause risk/harm to an individual |
# | Accountability | A data controller should be accountable for complying with measures that give effect to the other principles | How and when might a researcher to be held accountable and for what? |
#
#
# ### Exercise
#
# Choose a potential data source to analyze. You can draw from your potential MP3 project ideas or construct a hypothetical example.
# Select two of the principles above and discuss how specifically you would go about resolving the tension between protecting PII and performing desired analysis for this example data.

# %% [markdown]
# If I were to analyze news articles, I would only take articles from public media outlets. This would allow me to grab large sets of data while also ensuring that it is obtained lawfully and fairly. I would also only grab data from credible sources to ensure its accuracy.

# %% [markdown]
# ### Exercise
#
# Consider the "failure modes" of data analysis presented in Section 3.2.3.2 (overfitting, selection bias, cherry-picking, and confirmation bias).
#
# Select one of them and:
#  - define it in your own words
#  - describe how it might arise in the context of your MP3 project idea
#  - explain what you can do to guard against it

# %% [markdown]
# Confirmation bias is a type of bias exhibited by researchers who enter a problem space with a specific answer in mind, which ultimately prevents them from seeing the data as it truly is. In terms of analyzing news articles, confirmation bias can arise if I have preconceived notions about what the outputted article would look like. While this is inevitable, one way to guard against it is to have someone that is not me read the outputted article.

# %% [markdown]
# ## [Chapter 14.1-14.4](http://www.greenteapress.com/thinkpython2/html/thinkpython2015.html)
#
# Note: You've already seen the string formatting information in Chapter 14.3. The website [pyformat.info](https://pyformat.info/) is a great quick reference with many examples.
#
#
# ### Exercise
#
# The [os module](https://docs.python.org/3/library/os.html) provides a function called [walk](https://docs.python.org/3/library/os.html#os.walk) that is similar to the `walk` function written in Chapter 14.4 but more versatile.
#
# Read the documentation for `os.walk` and use it write a function that takes a directory and prints the names of the files in that directory and its subdirectories. After trying on your own you can reference [Allen's solution](http://thinkpython2.com/code/walk.py).

# %%
import os

def print_files(directory):
    """Print the names of files in given 'directory' and its subdirectories"""
    for root, dirs, files in os.walk(directory):
        for file in files:
            print(os.path.join(root, file))

print_files('.')
# Out:
# ./reading-journal-05.ipynb
# ./prideandprejudice.txt
# ./lizzo.txt
# ./README.md
# ./geometry.py
# ./reading-journal-09.ipynb
# ./.gitattributes
# ./reading-journal-03.ipynb
# ./reading-journal-02.ipynb
# ./shapes.py
# ./reading-journal-07.ipynb
# ./reading-journal-11.ipynb
# ./reading-journal-08.ipynb
# ./reading-journal-06.ipynb
# ./reading-journal-01.ipynb
# ./reading-journal-10.ipynb
# ./.gitignore
# ./reading-journal-04.ipynb
# ./words.txt
# ./.ipynb_checkpoints/reading-journal-04-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-05-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-06-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-11-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-08-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-03-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-01-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-02-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-09-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-10-checkpoint.ipynb
# ./.ipynb_checkpoints/reading-journal-07-checkpoint.ipynb
# ./.git/FETCH_HEAD
# ./.git/config
# ./.git/description
# ./.git/packed-refs
# ./.git/index
# ./.git/COMMIT_EDITMSG
# ./.git/ORIG_HEAD
# ./.git/HEAD
# ./.git/refs/remotes/upstream/master
# ./.git/refs/remotes/origin/master
# ./.git/refs/remotes/origin/HEAD
# ./.git/refs/heads/master
# ./.git/info/exclude
# ./.git/logs/HEAD
# ./.git/logs/refs/remotes/upstream/master
# ./.git/logs/refs/remotes/origin/master
# ./.git/logs/refs/remotes/origin/HEAD
# ./.git/logs/refs/heads/master
# ./.git/hooks/pre-receive.sample
# ./.git/hooks/pre-rebase.sample
# ./.git/hooks/pre-commit.sample
# ./.git/hooks/prepare-commit-msg.sample
# ./.git/hooks/commit-msg.sample
# ./.git/hooks/pre-push.sample
# ./.git/hooks/update.sample
# ./.git/hooks/post-update.sample
# ./.git/hooks/applypatch-msg.sample
# ./.git/hooks/pre-applypatch.sample
# ./.git/hooks/fsmonitor-watchman.sample
# ./.git/objects/31/4789682daa7d15f4d724a324fb5a5fa080d963
# ./.git/objects/7f/84eeaecdf7eec3f2dcf57f2d32ea39b5010fc2
# ./.git/objects/f7/a62c6d0b7d7b7f16d70e05f3b65bdaa4ca335a
# ./.git/objects/f7/17486415f1ed71c41caa32e7cacf5956b479e1
# ./.git/objects/f7/7ef8da113d1358f302024b8d6b58500028b218
# ./.git/objects/49/55157fba4261461b5256da4f00fd8f81c1d183
# ./.git/objects/84/a7f397e55e8766cd3214a89025822535c8fb1b
# ./.git/objects/4e/8d657c3b9b90a39529b64ff07bee964d0d335f
# ./.git/objects/24/fa431a9f45d5bcbb345d27353c7b7d1604b112
# ./.git/objects/46/f35d2a96180aaf1da088d5452d72a402dd38a6
# ./.git/objects/c9/861fde3ece17ac6aa84fc722da1cf740d4df73
# ./.git/objects/f5/f2b9501d3a14c3e4fa8efa301a07bb144b934f
# ./.git/objects/3c/e9f2d12ca5b00fd79a65e66a795b53a30f85a7
# ./.git/objects/3c/a4fc67fe3b435ac3d4052a5a54000f289e9f87
# ./.git/objects/95/9cac9a3e5413726cdab064793afe067dc61aad
# ./.git/objects/12/045f82de1563fa376876013ff894fe542c2034
# ./.git/objects/2f/634f918fd832aaae3c34c9b69c4106a46e2784
# ./.git/objects/42/f25351f4b6178e3b97829b56789794e5de3f5b
# ./.git/objects/ce/352405c48920ce7113d202b8b98e2b2c857184
# ./.git/objects/ce/2adbc57e0afb024e2e0fd146e765c3dd451f8a
# ./.git/objects/a2/ccb3aa72650f02fc4f835398e39764e667aa09
# ./.git/objects/82/239aeb8335efb16e7b8cff266dd67035444630
# ./.git/objects/60/1689d3c0f1556e721d3eb79216e2d1a6784813
# ./.git/objects/60/0c4b016612670ecc0cd02b9fe5b256f9b2fd80
# ./.git/objects/20/08aa3b05385d26c07decda0ed70e0133a598c2
# ./.git/objects/20/9df9a66a12b89c3cb745a864076b092c6d551b
# ./.git/objects/e3/1b316d5be736827c85c8a51efc541ff6d255b7
# ./.git/objects/a3/e556711e7ebb05c47ed85a823fcb9b3a484032
# ./.git/objects/07/94e1f3b271d8905e17508bfdc20ffe27023012
# ./.git/objects/b2/109be69a3a19e0472b3e1b4cc54269bcb2f091
# ./.git/objects/68/6b758fc8efbde82cfa2b6f57c5dbcfb12461d1
# ./.git/objects/c1/590585d67730bad143950faf750f01c7e8c5fb
# ./.git/objects/53/4991ce2d8adb97dff64bdaa78857c7471d0729
# ./.git/objects/a7/5db06baec37f92e12be5ec06b8a97f5d156ba3
# ./.git/objects/5f/fbd951983f837bd77cf75d354ec976924bf3e4
# ./.git/objects/b7/d56e4dd3965e19caa0b6a723fb5094f1d77d8b
# ./.git/objects/a5/303a59a9f14235a2e0caf8df3422048b4bd0fe
# ./.git/objects/75/8312f489f9f55a82248bd8a03a5558393d188e
# ./.git/objects/6f/4be75d1289718caea091df0a65f6d816c9f6b0
# ./.git/objects/3d/e5a14d9cf3806a24f27f5f1d07b89ff09d4852
# ./.git/objects/df/ac528ee014437d5d99387cee6613fbae6edcdc
# ./.git/objects/df/e0770424b2a19faf507a501ebfc23be8f54e7b
# ./.git/objects/15/216ffcc016c8b2bd06cd2d58114f1b8d34d0a6
# ./.git/objects/37/15dd62e5495858065556b1c1c9b6f829f0539c
# ./.git/objects/76/445c5ac7c054f4004b5fe6171e5b1c6d32bfa3
# ./.git/objects/ef/9afdaf624180e97a2dd3015f30de2936a770a4
# ./.git/objects/1a/b0f4e6b314ed2cbed9f24cf26284957b495ccb
# ./.git/objects/6e/8c03d6b17034cf41d99c5902e106c82b5ba7e5
# ./.git/objects/e7/3073a31b5a821f838a75ddece0e8cd4c33eb87
# ./.git/objects/c3/dceda4c2a77336eac28707fb716e1fedfe3935
# ./.git/objects/56/056ec1146ab275f26239675f8d3152d3635119
# ./.git/objects/2d/4e8b296d97ee6b459b8152ce56d1cd73458fa5
# ./.git/objects/9e/c4d93d99c67be25353f869fb8d92fe23306ea7
# ./.git/objects/e2/68fd9d464292e60a05b88d09f6118978ac7d96
# ./.git/objects/30/86eca3e9380d191b10331343edb898a9fcd493
# ./.git/objects/5a/add98dc5c6eca9d3b401ea63e774bc368bc8d8
# ./.git/objects/c6/5387e39a8ec5892d2781cd1c0a24fca4baa718
# ./.git/objects/ec/a1cf3942509dab9604251d9ca7c11988e87b8a
# ./.git/objects/48/968c22bb02d6fd5bb8863ceff6e097a08ef037
# ./.git/objects/93/adc65ef4dc332bb30353875749f600c0886565
# ./.git/objects/cd/2f54d13c34c83356e3f85f8730c97c41b8e5f9
# ./.git/objects/11/dd59c25a8c6f3fedffb3c96875a66bf5bea04b
# ./.git/objects/d3/983befc9ce900522cd06c39c2e11f9e6d1a774
# ./.git/objects/41/9e9f3f5aa22a184f8fbdee9f90fd5e68bb18b4
# ./.git/objects/26/18676ad2827f0cd870457fcca16fc39b1cada8
# ./.git/objects/86/84c69252a0d225de5708865bb98da3488d3656
# ./.git/objects/a9/95384982bddb4ac8e2a81f568ed2105c164c18
# ./.git/objects/ab/8833412b948b24ec5c9d6fabe54fc2b33abce7
# ./.git/objects/3f/b450f87813b743c3ffa8370f1bebeec4ce9da2
# ./.git/objects/3b/1ce1119040184751ed299a85f374254bfb05e3
# ./.git/objects/0d/7dc5bcf5df1646168f4d49c7459b2ec8b03995
# ./.git/objects/0a/d678522535bda3250f7bc0f95617deea1989a4
# ./.git/objects/cc/71273b1518472c0287969e3013116987cf4f45
# ./.git/objects/39/61dcd2060fc975f92576c3089fc502d3e6904f
# ./.git/objects/8a/b53a4a985a9d42d91442859a487979b2408935
# ./.git/objects/2c/c4f58c37efec78f009bd0ab72f58085fe5aebe
# ./.git/objects/9c/44ce91d7b9e6bb3d85bf07a0ca575529d1f0e7
# ./.git/objects/ac/9e7b5b297a1b4846def94ca6a189c773a1a58f
# ./.git/objects/14/dcacd3505d3ec0a92675aa42771ae318f5b03d
# ./.git/objects/14/8eada06d6925524bfa1c2f88cb7e0adcb7dbff
# ./.git/objects/78/324cfa23fefc91699f32706cc943f1e79d4709
# ./.git/objects/78/595b5ee29db6ff4611617e2c16a3fd925a6a11
# ./.git/objects/7e/291751e04755b13024a1fa712e3775d3cbbb5b
# ./.git/objects/e0/99792cf710358dad20079e52d6e030932c6096
# ./.git/objects/e0/68a71f0482c254f72abab71f672dfbac37caa0
# ./.git/objects/61/a1cc2f70fd87407f4891b2af1e96d75e995b88
# ./.git/objects/61/93e87b5b3b97fd9d2537eb6a51669646e5fbf5
# ./.git/objects/fc/d6db93e3307276510e22f0d80956edb65354b8

# %% [markdown]
# ### Exercise
#
# Write a function called `sed` that takes as arguments a pattern string, a replacement string, and two filenames.
# It should read the first file and write the contents into the second file (creating it if necessary). If the pattern string appears anywhere in the first file, it should be replaced with the replacement string when written into the second file.
#
# _Note_: Be careful as you write and test this function not to overwrite files you care about!
#
# After trying on your own you can reference [Allen's solution](http://thinkpython2.com/code/sed.py). You do not need to handle Exceptions at this point.

# %%
def sed(pattern, replacement, src_fn, dest_fn):
    """Reads first file and writes the contents into the second file
    
    pattern: pattern string
    replacement: replacement string
    src_fn: file being read
    dest_fn: file being written in
    """
    src = open(src_fn, 'r')
    dest = open(dest_fn, 'w')
    for line in src:
        line = line.replace(pattern, replacement)
        dest.write(line)
    src.close()
    dest.close()

sed('Mr. Bennet', 'Marion', 'prideandprejudice.txt', 'prideandprejustice2.txt')
